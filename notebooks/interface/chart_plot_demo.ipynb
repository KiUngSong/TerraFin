# %%
from TerraFin import configure, load_terrafin_config
from TerraFin.data import DataFactory
from TerraFin.interface import display_chart_notebook


configure()
config = load_terrafin_config()

data_factory = DataFactory()
df1 = data_factory.get("S&P 500")
df2 = data_factory.get("Kospi")
df3 = data_factory.get("Nasdaq")
df4 = data_factory.get("Fear & Greed")

display_chart_notebook(
    [
        df1,
        df2,
        df3,
        df4,
    ]
)
