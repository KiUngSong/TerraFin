# %%
from TerraFin import configure, load_terrafin_config
from TerraFin.data import DataFactory
from TerraFin.data.providers.corporate.investor_positioning import ALL_GURUS


configure()
config = load_terrafin_config()

print(ALL_GURUS)

factory = DataFactory()
port = factory.get_portfolio_data("Bill Ackman")
print(port.info)
print(port.df.head())

# %%
fig = port.df.make_figure()
fig.show()
